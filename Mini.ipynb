# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('fish1.csv')
print("Dataset Loaded Successfully")
# Out:
# Dataset Loaded Successfully

# %%
data.shape
# Out:
# (103, 19)

# %%
data.columns
# Out:
# Index(['Name', 'Energy (Kcals)', 'Moisture (g)', 'Protein (g)', 'Fat (g)',
#        'Mineral (g)', 'Carbohydrates (g)', 'Calcium (mg)', 'Phosphorus (mg)',
#        'Iron (mg)', 'Price per kg', 'Blood Pressure', 'Heart Disease',
#        'Brain Health', 'Autoimmune Diseases', 'Prevent Asthma', 'Bone Health',
#        'Eye', 'Cancer'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 103 non-null    object
#  1   Energy (Kcals)       103 non-null    int64
#  2   Moisture (g)         103 non-null    int64
#  3   Protein (g)          103 non-null    int64
#  4   Fat (g)              103 non-null    int64
#  5   Mineral (g)          103 non-null    float64
#  6   Carbohydrates (g)    103 non-null    int64
#  7   Calcium (mg)         103 non-null    int64
#  8   Phosphorus (mg)      103 non-null    int64
#  9   Iron (mg)            103 non-null    int64
#  10  Price per kg         103 non-null    int64
#  11  Blood Pressure       103 non-null    int64
#  12  Heart Disease        103 non-null    int64
#  13  Brain Health         103 non-null    int64
#  14  Autoimmune Diseases  103 non-null    int64
# ...

# %%
data.head()
# Out:
#              Name  Energy (Kcals)  Moisture (g)  Protein (g)  Fat (g)  \
# 0             air              89            78           16        1
# 1         anchovy             164            69           19       10
# 2           bacha             147            69           18        6
# 3             bam             100            70           16        1
# 4  baspata machli             112            76           18        4
#
#    Mineral (g)  Carbohydrates (g)  Calcium (mg)  Phosphorus (mg)  Iron (mg)  \
# 0          1.0                  3           380              180          1
# 1          2.0                  0           143              174          1
# 2          1.0                  6           520              180          1
# 3          1.0                  7           330              240          1
# 4          1.0                  0           175              225          0
#
#    Price per kg  Blood Pressure  Heart Disease  Brain Health  \
# ...

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.isna().sum()
# Out:
# Name                   0
# Energy (Kcals)         0
# Moisture (g)           0
# Protein (g)            0
# Fat (g)                0
# Mineral (g)            0
# Carbohydrates (g)      0
# Calcium (mg)           0
# Phosphorus (mg)        0
# Iron (mg)              0
# Price per kg           0
# Blood Pressure         0
# Heart Disease          0
# Brain Health           0
# Autoimmune Diseases    0
# Prevent Asthma         0
# Bone Health            0
# Eye                    0
# Cancer                 0
# dtype: int64

# %%
index=data[data['Heart Disease']==1].index
res=data[['Name','Price per kg']].loc[index]
res
# Out:
#                    Name  Price per kg
# 1               anchovy           150
# 10         bhekti fresh           250
# 11         bhekti dried           200
# 14                 boal           100
# 15   bombay duck, dried            50
# 16          blue mussel           100
# 23                 crab           450
# 24           crab small           300
# 25                folui           200
# 27              goggler           250
# 28      herring, indian           200
# 30       horse mackerel           350
# 31       indian whiting           100
# 32                hilsa           300
# 36                katla           200
# 38         khorya fresh           150
# 39         khorya dried           100
# 40                  koi           400
# 42                 lata           100
# 44             mackerel           400
# 47              mandeli           100
# 48               mrigal           250
# 50                mushi           350
# 51               mussel           150
# ...

# %%
index=data[data['Blood Pressure']==1].index
res=data[['Name','Price per kg']].loc[index]
res
# Out:
#                    Name  Price per kg
# 1               anchovy           150
# 9          bhangan bata           200
# 15   bombay duck, dried            50
# 16          blue mussel           100
# 18                chela           200
# 19          chela dried           150
# 20  chingri small dried           300
# 21  chingri goda, dried           700
# 28      herring, indian           200
# 30       horse mackerel           350
# 31       indian whiting           100
# 32                hilsa           300
# 33       jew fish- kora           150
# 34   jew fish-pallikora           200
# 36                katla           200
# 44             mackerel           400
# 48               mrigal           250
# 51               mussel           150
# 52            mutijella           200
# 60                prawn           600
# 62                ravas           100
# 64    ribbon fish fresh           200
# 65   ribbon fish, dried           150
# 72         silver belly           150
# ...

# %%
index=data[data['Brain Health']==1].index
res=data[['Name','Price per kg']].loc[index]
res
# Out:
#                    Name  Price per kg
# 3                   bam           175
# 10         bhekti fresh           250
# 11         bhekti dried           200
# 12                bhola           250
# 58      pomfrets, black           350
# 59      pomfrets, white           500
# 64    ribbon fish fresh           200
# 65   ribbon fish, dried           150
# 68              sarputi           100
# 71                 seer           600
# 74               singhi           200
# 102                 gar           175

# %%
index=data[data['Bone Health']==1].index
res=data[['Name','Price per kg']].loc[index]
res
# Out:
#                    Name  Price per kg
# 2                 bacha           400
# 3                   bam           175
# 4        baspata machli           200
# 13     big jawed jumper           300
# 18                chela           200
# 19          chela dried           150
# 33       jew fish- kora           150
# 34   jew fish-pallikora           200
# 40                  koi           400
# 43              lobster           900
# 44             mackerel           400
# 48               mrigal           250
# 58      pomfrets, black           350
# 59      pomfrets, white           500
# 62                ravas           100
# 74               singhi           200
# 77        surmai, fresh           450
# 78        surmai, dried           400
# 88              tilapia            60
# 90               angler           900
# 92             albacore           100
# 99            eagle ray           400
# 102                 gar           175

# %%
index=data[data['Eye']==1].index
res=data[['Name','Price per kg']].loc[index]
res
# Out:
#                   Name  Price per kg
# 6                beley           120
# 10        bhekti fresh           250
# 11        bhekti dried           200
# 12               bhola           250
# 26                ghol           350
# 29     herring ox-eyed           250
# 33      jew fish- kora           150
# 34  jew fish-pallikora           200
# 36               katla           200
# 42                lata           100
# 58     pomfrets, black           350
# 59     pomfrets, white           500
# 62               ravas           100
# 63                 ray           125
# 64   ribbon fish fresh           200
# 65  ribbon fish, dried           150
# 74              singhi           200
# 81             tartoor           300
# 89             croaker           300
# 92            albacore           100

# %%
index=data[data['Cancer']==1].index
res=data[['Name','Price per kg']].loc[index]
res
# Out:
#                Name  Price per kg
# 14             boal           100
# 28  herring, indian           200
# 40              koi           400
# 45            magur           100
# 69            shark           250
# 81          tartoor           300

# %%
data['Prevent Asthma']=data['Prevent Asthma'].astype('int64')

# %%
data['Mineral (g)']=data['Mineral (g)'].astype('int64')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 103 non-null    object
#  1   Energy (Kcals)       103 non-null    int64
#  2   Moisture (g)         103 non-null    int64
#  3   Protein (g)          103 non-null    int64
#  4   Fat (g)              103 non-null    int64
#  5   Mineral (g)          103 non-null    int64
#  6   Carbohydrates (g)    103 non-null    int64
#  7   Calcium (mg)         103 non-null    int64
#  8   Phosphorus (mg)      103 non-null    int64
#  9   Iron (mg)            103 non-null    int64
#  10  Price per kg         103 non-null    int64
#  11  Blood Pressure       103 non-null    int64
#  12  Heart Disease        103 non-null    int64
#  13  Brain Health         103 non-null    int64
#  14  Autoimmune Diseases  103 non-null    int64
# ...

# %%
data.head()
# Out:
#              Name  Energy (Kcals)  Moisture (g)  Protein (g)  Fat (g)  \
# 0             air              89            78           16        1
# 1         anchovy             164            69           19       10
# 2           bacha             147            69           18        6
# 3             bam             100            70           16        1
# 4  baspata machli             112            76           18        4
#
#    Mineral (g)  Carbohydrates (g)  Calcium (mg)  Phosphorus (mg)  Iron (mg)  \
# 0            1                  3           380              180          1
# 1            2                  0           143              174          1
# 2            1                  6           520              180          1
# 3            1                  7           330              240          1
# 4            1                  0           175              225          0
#
#    Price per kg  Blood Pressure  Heart Disease  Brain Health  \
# ...

# %%
data.columns
# Out:
# Index(['Name', 'Energy (Kcals)', 'Moisture (g)', 'Protein (g)', 'Fat (g)',
#        'Mineral (g)', 'Carbohydrates (g)', 'Calcium (mg)', 'Phosphorus (mg)',
#        'Iron (mg)', 'Price per kg', 'Blood Pressure', 'Heart Disease',
#        'Brain Health', 'Autoimmune Diseases', 'Prevent Asthma', 'Bone Health',
#        'Eye', 'Cancer'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 103 non-null    object
#  1   Energy (Kcals)       103 non-null    int64
#  2   Moisture (g)         103 non-null    int64
#  3   Protein (g)          103 non-null    int64
#  4   Fat (g)              103 non-null    int64
#  5   Mineral (g)          103 non-null    int64
#  6   Carbohydrates (g)    103 non-null    int64
#  7   Calcium (mg)         103 non-null    int64
#  8   Phosphorus (mg)      103 non-null    int64
#  9   Iron (mg)            103 non-null    int64
#  10  Price per kg         103 non-null    int64
#  11  Blood Pressure       103 non-null    int64
#  12  Heart Disease        103 non-null    int64
#  13  Brain Health         103 non-null    int64
#  14  Autoimmune Diseases  103 non-null    int64
# ...

# %%
data.isna().sum()
# Out:
# Name                   0
# Energy (Kcals)         0
# Moisture (g)           0
# Protein (g)            0
# Fat (g)                0
# Mineral (g)            0
# Carbohydrates (g)      0
# Calcium (mg)           0
# Phosphorus (mg)        0
# Iron (mg)              0
# Price per kg           0
# Blood Pressure         0
# Heart Disease          0
# Brain Health           0
# Autoimmune Diseases    0
# Prevent Asthma         0
# Bone Health            0
# Eye                    0
# Cancer                 0
# dtype: int64

# %%
data.hist(figsize=(16,10))
plt.show()

# %%
# column = data['Price per kg']
# column.max()

# %%
# s = data.set_index('Name')['Price per kg'].agg(['max','idxmax'])
# print (s['max'])
# 9
# print (s['idxmax'])

# %%
max_price = data[data['Price per kg'] == data['Price per kg'].max()]
print(max_price[['Name','Price per kg']])
# Out:
#        Name  Price per kg
# 43  lobster           900
# 90   angler           900

# %%
# for i in data.columns[1:]:
#     print(data[i].value_counts().sort_index(ascending=False).head(10))

# %%
y=data['Energy (Kcals)'].nlargest(10)
y.values
# Out:
# array([413, 383, 349, 343, 334, 334, 312, 312, 296, 293], dtype=int64)

# %%
y.index
# Out:
# Int64Index([19, 65, 70, 80, 79, 96, 50, 57, 39, 15], dtype='int64')

# %%
x=data['Name'].iloc[y.index]
x.values
# Out:
# array(['chela dried', 'ribbon fish, dried', 'shrimp(smalldried)', 'tapsi',
#        'tapra', 'candlefish', 'mushi', 'parsey dried', 'khorya dried',
#        'bombay duck, dried'], dtype=object)

# %%
plt.figure(figsize=(16,8))
sns.barplot(x.values,y.values)
# Out:
# <AxesSubplot:>

# %%
 data['Protein (g)'].nlargest(10)
# Out:
# 65    76
# 70    68
# 50    67
# 57    65
# 52    64
# 15    62
# 20    62
# 79    62
# 96    62
# 11    60
# Name: Protein (g), dtype: int64

# %%
a = data.filter(["Energy (Kcals)","Name"])
a =a.nlargest(10,'Energy (Kcals)')
a
# Out:
#     Energy (Kcals)                Name
# 19             413         chela dried
# 65             383  ribbon fish, dried
# 70             349  shrimp(smalldried)
# 80             343               tapsi
# 79             334               tapra
# 96             334          candlefish
# 50             312               mushi
# 57             312        parsey dried
# 39             296        khorya dried
# 15             293  bombay duck, dried

# %%
a = data.filter(["Protein (g)","Name"])
a =a.nlargest(10,'Protein (g)')
a
# Out:
#     Protein (g)                 Name
# 65           76   ribbon fish, dried
# 70           68   shrimp(smalldried)
# 50           67                mushi
# 57           65         parsey dried
# 52           64            mutijella
# 15           62   bombay duck, dried
# 20           62  chingri small dried
# 79           62                tapra
# 96           62           candlefish
# 11           60         bhekti dried

# %%
a = data.filter(["Mineral (g)","Name"])
a =a.nlargest(10,'Mineral (g)')
a
# Out:
#      Mineral (g)                 Name
# 83            27         tengra dried
# 97            27                catla
# 100           27              escolar
# 21            17  chingri goda, dried
# 70            17   shrimp(smalldried)
# 80            17                tapsi
# 8             16         bhagon dried
# 11            16         bhekti dried
# 39            16         khorya dried
# 57            16         parsey dried

# %%
a = data.filter(["Calcium (mg)","Name"])
a =a.nlargest(10,'Calcium (mg)')
a
# Out:
#     Calcium (mg)                 Name
# 52          7240            mutijella
# 8           6235         bhagon dried
# 91          6235               bonito
# 70          4384   shrimp(smalldried)
# 21          3847  chingri goda, dried
# 19          3590          chela dried
# 20          3539  chingri small dried
# 57          2231         parsey dried
# 24          1606           crab small
# 80          1597                tapsi

# %%
a = data.filter(["Phosphorus (mg)","Name"])
a =a.nlargest(10,'Phosphorus (mg)')
a
# Out:
#     Phosphorus (mg)                 Name
# 19             2342          chela dried
# 70             1160   shrimp(smalldried)
# 52              834            mutijella
# 21              828  chingri goda, dried
# 72              741         silver belly
# 98              741              devario
# 65              700   ribbon fish, dried
# 87              657                cobia
# 74              650               singhi
# 80              595                tapsi

# %%
a = data.filter(["Iron (mg)","Name",'Price per kg'])
a =a.nlargest(10,'Iron (mg)')
x=a['Name'].values
y=a['Price per kg'].values

# %%
plt.figure(figsize=(16,8))
plt.pie(y,labels=x,autopct="%d")
ax = plt.axes()
plt.show()

# %%
da=data['Iron (mg)'].nlargest(10)
da.index
data[['Name','Price per kg']].loc[da.index]
# Out:
#                    Name  Price per kg
# 21  chingri goda, dried           700
# 80                tapsi           150
# 20  chingri small dried           300
# 23                 crab           450
# 15   bombay duck, dried            50
# 79                tapra           200
# 96           candlefish           200
# 57         parsey dried           200
# 11         bhekti dried           200
# 64    ribbon fish fresh           200

# %%
a = data.filter(["Price per kg","Name"])
a =a.nlargest(10,'Price per kg')
a
# Out:
#      Price per kg                 Name
# 43            900              lobster
# 90            900               angler
# 21            700  chingri goda, dried
# 60            600                prawn
# 71            600                 seer
# 94            600             bandfish
# 84            550                tunny
# 101           550          finger fish
# 59            500      pomfrets, white
# 23            450                 crab

# %%
sns.regplot(x=data["Energy (Kcals)"], y=data["Fat (g)"])
# Out:
# <AxesSubplot:xlabel='Energy (Kcals)', ylabel='Fat (g)'>

# %%
sns.kdeplot(data['Price per kg'],color='r',fill='blue')
# Out:
# <AxesSubplot:xlabel='Price per kg', ylabel='Density'>

# %%
sns.kdeplot(data['Energy (Kcals)'],color='r',fill='blue')
# Out:
# <AxesSubplot:xlabel='Energy (Kcals)', ylabel='Density'>

# %%
fig = plt.figure(figsize=(20,14))

#  subplot #1
plt.subplot(231)
plt.title('For Blood Pressure')
sns.countplot(data = data, x='Blood Pressure')

#  subplot #2
plt.subplot(2,3,2)
plt.title('For Heart Disease')
sns.countplot(data = data, x='Heart Disease')

#  subplot #3
plt.subplot(233)
plt.title('For Brain Health')
sns.countplot(data = data, x='Brain Health')

# #  subplot #4
plt.subplot(2,3,4)
plt.title('For Eye')
sns.countplot(data = data, x='Eye')

# # subplot #5
plt.subplot(235)
plt.title('For Cancer')
sns.countplot(data = data, x='Cancer')

# # subplot #6
plt.subplot(2,3,6)
plt.title('For Bone Health')
sns.countplot(data = data, x='Bone Health')
plt.show()

# %% [markdown]
# #

# %%
plt.figure(figsize=(20,10))
data.boxplot()
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(data,hue='Price per kg')

# %%
x=data.drop(['Name','Price per kg'],axis=1)
y=data['Price per kg']

# %%
plt.figure(figsize=(16,8))
sns.heatmap(x.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
from sklearn.feature_selection import SelectKBest,f_classif,chi2

# %%
columns=x.columns
columns
# Out:
# Index(['Energy (Kcals)', 'Moisture (g)', 'Protein (g)', 'Fat (g)',
#        'Mineral (g)', 'Carbohydrates (g)', 'Calcium (mg)', 'Phosphorus (mg)',
#        'Iron (mg)', 'Blood Pressure', 'Heart Disease', 'Brain Health',
#        'Autoimmune Diseases', 'Prevent Asthma', 'Bone Health', 'Eye',
#        'Cancer'],
#       dtype='object')

# %%
new_feature = SelectKBest(chi2,k=4).fit(x,y)
index=new_feature.get_support(indices=True)

# %%
col=columns[index]

# %%
x = x.drop(['Cancer','Prevent Asthma','Autoimmune Diseases','Blood Pressure','Heart Disease','Eye','Brain Health','Carbohydrates (g)','Bone Health'],axis=1)

# %%
x
# Out:
#      Energy (Kcals)  Moisture (g)  Protein (g)  Fat (g)  Mineral (g)  \
# 0                89            78           16        1            1
# 1               164            69           19       10            2
# 2               147            69           18        6            1
# 3               100            70           16        1            1
# 4               112            76           18        4            1
# ..              ...           ...          ...      ...          ...
# 98               91            66           19        2            3
# 99              210            43           39        6            6
# 100             255            14           55       45           27
# 101             113            72           24        2            2
# 102             100            70           16        1            1
#
#      Calcium (mg)  Phosphorus (mg)  Iron (mg)
# 0             380              180          1
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=0)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model.fit(x_train,y_train)
pred = model.predict(x_test)

# %%
y_test
# Out:
# 26    350
# 60    600
# 2     400
# 51    150
# 71    600
# 76    150
# 16    100
# 66    300
# 56    250
# 48    250
# 54    150
# 95    250
# 98    150
# 13    300
# 7     150
# 30    350
# 22    250
# 24    300
# 33    150
# 8     100
# 43    900
# 75    100
# 3     175
# 73    150
# 85     75
# 74    200
# 6     120
# 45    100
# 96    200
# 78    400
# 62    100
# Name: Price per kg, dtype: int64

# %%
pred
# Out:
# array([270.66422162, 292.93644294, 203.60672804, 279.95651717,
#        303.63194266, 260.07045767, 306.12213246, 250.7323    ,
#        266.36433538, 264.9423424 , 242.91565873, 254.03557067,
#        319.85306301, 257.14223521, 186.312861  , 277.79375626,
#        254.03557067, 158.1817205 , 296.39984955, 160.86569865,
#        264.45848036, 225.39033867, 243.0492146 , 176.59400757,
#        290.11500007, 279.93099206, 264.01423039, 265.22282475,
#        189.05734184, 179.69022413, 262.9736707 ])

# %%
res=pd.DataFrame({'y_test':list(y_test),'pred':list(pred)})
res
# Out:
#     y_test        pred
# 0      350  270.664222
# 1      600  292.936443
# 2      400  203.606728
# 3      150  279.956517
# 4      600  303.631943
# 5      150  260.070458
# 6      100  306.122132
# 7      300  250.732300
# 8      250  266.364335
# 9      250  264.942342
# 10     150  242.915659
# 11     250  254.035571
# 12     150  319.853063
# 13     300  257.142235
# 14     150  186.312861
# 15     350  277.793756
# 16     250  254.035571
# 17     300  158.181721
# 18     150  296.399850
# 19     100  160.865699
# 20     900  264.458480
# 21     100  225.390339
# 22     175  243.049215
# 23     150  176.594008
# 24      75  290.115000
# 25     200  279.930992
# 26     120  264.014230
# 27     100  265.222825
# 28     200  189.057342
# 29     400  179.690224
# 30     100  262.973671

# %%
from sklearn.metrics import accuracy_score,r2_score

# %%
r2_score(y_test,pred)*100*3
# Out:
# -3.9564680061046076
